# %% [markdown]
# # Challenge Set 1:  MTA Turnstile Data

# %%
from __future__ import print_function, division

# %%
import pandas as pd
import thinkstats2 

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

# %%
import datetime

# %% [markdown]
# #### Exercise 1.1
#
# - Open up a new Jupyter notebook
# - Download a few MTA turnstile data files
# - Open up a file, use csv reader to read it, make a python dict where
#   there is a key for each (C/A, UNIT, SCP, STATION). These are the
#   first four columns. The value for this key should be a list of
#   lists. Each list in the list is the rest of the columns in a
#   row. For example, one key-value pair should look like
#
#
# {    ('A002','R051','02-00-00','LEXINGTON AVE'):
# [
# ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'],
# ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'],
# ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'],
# ...
# ]
# }

# %%
# To Plot matplotlib figures inline on the notebook
# %matplotlib inline

from urllib.request import urlopen

url12 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170513.txt'
df = pd.read_csv(url12)
df.columns = df.columns.str.lower()
# df1.columns = df1.columns.str.lower()
# url6 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170401.txt'
# df6=pd.read_csv(url6)
# url7 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170408.txt'
# df7 = pd.read_csv(url7)
# url8 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170415.txt'
# df8 = pd.read_csv(url8)
# url9 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170422.txt'
# df9 = pd.read_csv(url9)
# url10 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170429.txt'
# df10 = pd.read_csv(url10)
# url11 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170506.txt'
# df11 = pd.read_csv(url11)

# url13 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170520.txt'
# df13= pd.read_csv(url13)
# url14 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170527.txt'
# df14= pd.read_csv(url14)



# frames = [df6, df7, df8, df9,\
#         df10, df11, df12, df13,df14,]

# df1 = pd.concat(frames)

# %%
url12 = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170513.txt'
df = pd.read_csv(url12)
df.columns = df.columns.str.lower()
# df1.columns = df1.columns.str.lower()
# df2.columns = df2.columns.str.lower()

#df.drop(['c/a','unit','scp','linename', 'division', 
       # 'desc'], axis = 1, inplace = True)

# %%
df.dtypes
a = len(df)
print (a)
df.replace('0', np.NaN)
df.dropna(inplace = True)
b = len(df)
c = a -b
print ( str(c) + ' rows removed')
b
df
# Out:
# 196861
# 0 rows removed
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/06/2017
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/06/2017
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/06/2017
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/06/2017
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/06/2017
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/06/2017
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/07/2017
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/07/2017
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/07/2017
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/07/2017
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/07/2017
# 11       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/07/2017
# 12       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/08/2017
# 13       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/08/2017
# 14       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/08/2017
# 15       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/08/2017
# 16       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/08/2017
# 17       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/08/2017
# 18       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/09/2017
# 19       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/09/2017
# 20       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/09/2017
# 21       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/09/2017
# 22       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/09/2017
# 23       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/09/2017
# 24       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/10/2017
# 25       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/10/2017
# 26       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/10/2017
# 27       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/10/2017
# 28       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/10/2017
# 29       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/10/2017
# ...       ...   ...       ...            ...      ...      ...         ...
# 196831  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/08/2017
# 196832  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/08/2017
# 196833  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/08/2017
# 196834  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/08/2017
# 196835  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/09/2017
# 196836  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/09/2017
# 196837  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/09/2017
# 196838  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/09/2017
# 196839  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/09/2017
# 196840  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/09/2017
# 196841  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/09/2017
# 196842  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/09/2017
# 196843  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/10/2017
# 196844  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/10/2017
# 196845  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/10/2017
# 196846  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/10/2017
# 196847  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/10/2017
# 196848  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/10/2017
# 196849  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/11/2017
# 196850  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/11/2017
# 196851  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/11/2017
# 196852  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/11/2017
# 196853  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/11/2017
# 196854  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/11/2017
# 196855  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/12/2017
# 196856  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/12/2017
# 196857  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/12/2017
# 196858  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/12/2017
# 196859  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/12/2017
# 196860  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/12/2017
#
#             time     desc  entries  \
# 0       00:00:00  REGULAR  6166390
# 1       04:00:00  REGULAR  6166420
# 2       08:00:00  REGULAR  6166433
# 3       12:00:00  REGULAR  6166514
# 4       16:00:00  REGULAR  6166791
# 5       20:00:00  REGULAR  6167090
# 6       00:00:00  REGULAR  6167259
# 7       04:00:00  REGULAR  6167284
# 8       08:00:00  REGULAR  6167297
# 9       12:00:00  REGULAR  6167402
# 10      16:00:00  REGULAR  6167605
# 11      20:00:00  REGULAR  6167857
# 12      00:00:00  REGULAR  6167955
# 13      04:00:00  REGULAR  6167963
# 14      08:00:00  REGULAR  6168003
# 15      12:00:00  REGULAR  6168197
# 16      16:00:00  REGULAR  6168523
# 17      20:00:00  REGULAR  6169303
# 18      00:00:00  REGULAR  6169536
# 19      04:00:00  REGULAR  6169566
# 20      08:00:00  REGULAR  6169600
# 21      12:00:00  REGULAR  6169748
# 22      16:00:00  REGULAR  6170086
# 23      20:00:00  REGULAR  6170839
# 24      00:00:00  REGULAR  6171059
# 25      04:00:00  REGULAR  6171075
# 26      08:00:00  REGULAR  6171120
# 27      12:00:00  REGULAR  6171297
# 28      16:00:00  REGULAR  6171646
# 29      20:00:00  REGULAR  6172382
# ...          ...      ...      ...
# 196831  13:00:00  REGULAR     5554
# 196832  17:00:00  REGULAR     5554
# 196833  17:45:33  REGULAR     5554
# 196834  21:00:00  REGULAR     5554
# 196835  01:00:00  REGULAR     5554
# 196836  05:00:00  REGULAR     5554
# 196837  08:01:01  REGULAR     5554
# 196838  08:58:36  REGULAR     5554
# 196839  09:00:00  REGULAR     5554
# 196840  13:00:00  REGULAR     5554
# 196841  17:00:00  REGULAR     5554
# 196842  21:00:00  REGULAR     5554
# 196843  01:00:00  REGULAR     5554
# 196844  05:00:00  REGULAR     5554
# 196845  09:00:00  REGULAR     5554
# 196846  13:00:00  REGULAR     5554
# 196847  17:00:00  REGULAR     5554
# 196848  21:00:00  REGULAR     5554
# 196849  01:00:00  REGULAR     5554
# 196850  05:00:00  REGULAR     5554
# 196851  09:00:00  REGULAR     5554
# 196852  13:00:00  REGULAR     5554
# 196853  17:00:00  REGULAR     5554
# 196854  21:00:00  REGULAR     5554
# 196855  01:00:00  REGULAR     5554
# 196856  05:00:00  REGULAR     5554
# 196857  09:00:00  REGULAR     5554
# 196858  13:00:00  REGULAR     5554
# 196859  17:00:00  REGULAR     5554
# 196860  21:00:00  REGULAR     5554
#
#         exits
# 0                                                 2088519
# 1                                                 2088525
# 2                                                 2088557
# 3                                                 2088663
# 4                                                 2088720
# 5                                                 2088765
# 6                                                 2088794
# 7                                                 2088800
# 8                                                 2088823
# 9                                                 2088901
# 10                                                2088973
# 11                                                2089024
# 12                                                2089043
# 13                                                2089044
# 14                                                2089156
# 15                                                2089447
# 16                                                2089518
# 17                                                2089586
# 18                                                2089615
# 19                                                2089618
# 20                                                2089740
# 21                                                2089991
# 22                                                2090064
# 23                                                2090126
# 24                                                2090152
# 25                                                2090156
# 26                                                2090282
# 27                                                2090569
# 28                                                2090657
# 29                                                2090821
# ...                                                   ...
# 196831                                                299
# 196832                                                299
# 196833                                                299
# 196834                                                299
# 196835                                                299
# 196836                                                299
# 196837                                                299
# 196838                                                299
# 196839                                                299
# 196840                                                299
# 196841                                                299
# 196842                                                299
# 196843                                                299
# 196844                                                299
# 196845                                                299
# 196846                                                299
# 196847                                                299
# 196848                                                299
# 196849                                                299
# 196850                                                299
# 196851                                                299
# 196852                                                299
# 196853                                                299
# 196854                                                299
# 196855                                                299
# 196856                                                299
# 196857                                                299
# 196858                                                299
# 196859                                                299
# 196860                                                299
#
# [196861 rows x 11 columns]

# %%
print (len(df))
df = df[df.station != 'JOURNAL SQUARE']

print (len(df))

# %%
from pylab import figure, axes, pie, title, show
#df.groupby(['station', 'date','time']).mean().sort_values('entries')
##df.groupby(['station', 'datetime']).mean().sort_values('exits', ascending =False)
# df.groupby(['station' ])[["entries"]].sum().sort_values('entries',ascending =False).head(20).plot(kind= 'barh')


# plt.savefig('foo.png', bbox_inches='tight')

# %%
# Out:
# Empty DataFrame
# Columns: [c/a, unit, scp, station, linename, division, date, time, desc, entries, exits                                                               ]
# Index: []

# %%
print (len(df))
df = df[df.station != 'JOURNAL SQUARE']

print (len(df))
# Out:
# 196861
# 196005

# %%
mask = ['station', 'linename', 'scp', 'unit', 'c/a']
df.groupby(mask)[['entries']].max() - df.groupby(mask)[["entries"]].min()

# df_monthly.loc['EASTCHSTER/DYRE']
#df[(df['station']=='1 AV') & (df['scp']=='00-00-00') & (df['linename']=='L')]
# df_monthly = df_monthly.groupby(['station','linename'])['entries'].sum()
# df_monthly.sort_values(ascending=False).head(20).plot(kind='barh')
# df_monthly.sort_values(axis=1, ascending=False).head(20).plot(kind='barh')
# Out:
#                                               entries
# station         linename scp      unit c/a
# 1 AV            L        00-00-00 R248 H007     18193
#                          00-00-01 R248 H007     23692
#                          00-03-00 R248 H007      7626
#                          00-03-01 R248 H007      5585
#                          00-03-02 R248 H007      6359
#                          01-00-00 R248 H008      1393
#                          01-00-01 R248 H008      3562
#                          01-00-02 R248 H008      7520
#                          01-00-03 R248 H008     13772
#                          01-00-04 R248 H008     21755
# 103 ST          1        00-00-00 R191 R170     20956
#                          00-00-01 R191 R170     15126
#                          00-00-02 R191 R170     17693
#                          00-03-00 R191 R170      7257
#                          00-03-01 R191 R170      9300
#                          00-03-02 R191 R170     11846
#                 6        00-00-00 R180 R252     20492
#                          00-00-01 R180 R252     17575
#                          00-00-02 R180 R252     18059
#                          00-03-00 R180 R252     12839
#                          00-03-01 R180 R252      9768
#                          00-03-02 R180 R252     12562
#                 BC       00-00-00 R314 N037     15048
#                          00-00-01 R314 N037     10508
#                          00-00-02 R314 N037      5337
# 103 ST-CORONA   7        00-00-00 R208 R529     12805
#                          00-00-01 R208 R529     11201
#                          00-00-02 R208 R529     13928
#                          00-00-03 R208 R529     22801
#                          00-00-04 R208 R529     15280
# ...                                               ...
# WOODHAVEN BLVD  MR       00-03-04 R201 N329     12990
#                          01-05-00 R201 N329A        4
#                          01-05-01 R201 N329A        0
#                          01-06-00 R201 N329A    23115
#                          01-06-01 R201 N329A    15914
# WOODLAWN        4        00-00-00 R052 R294     12705
#                          00-00-01 R052 R294      8088
#                          00-00-02 R052 R294      6497
#                          00-00-03 R052 R294      7559
#                          00-00-04 R052 R294     11745
# WORLD TRADE CTR ACE23    01-00-00 R029 N094      9968
#                          01-00-01 R029 N094      5037
#                          01-00-02 R029 N094     14413
#                          01-00-03 R029 N094     18372
#                          01-05-00 R029 N094         3
#                          01-05-01 R029 N094         0
#                          01-06-00 R029 N094      9785
#                          01-06-01 R029 N094     16686
#                          01-06-02 R029 N094      6839
#                          01-06-03 R029 N094     12909
#                          01-06-04 R029 N094      3350
# YORK ST         F        00-00-00 R301 N530     23330
#                          00-00-01 R301 N530     23833
#                          00-00-02 R301 N530     18956
# ZEREGA AV       6        00-00-00 R326 R419      2254
#                          00-00-01 R326 R419      2141
#                          00-03-00 R326 R419      4809
#                          00-03-01 R326 R419      7532
#                          00-05-00 R326 R419         0
#                          00-05-01 R326 R419         0
#
# [4667 rows x 1 columns]

# %%
df.groupby(['station','linename'])['entries'].sum().sort_values(ascending=False).head(20).plot(kind= 'barh')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196005 entries, 0 to 196860
# Data columns (total 11 columns):
# c/a                                                                     196005 non-null object
# unit                                                                    196005 non-null object
# scp                                                                     196005 non-null object
# station                                                                 196005 non-null object
# linename                                                                196005 non-null object
# division                                                                196005 non-null object
# date                                                                    196005 non-null object
# time                                                                    196005 non-null object
# desc                                                                    196005 non-null object
# entries                                                                 196005 non-null int64
# exits                                                                   196005 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 17.9+ MB

# %%
##REMOVE JOURNAL SQ AS OUTLIER


sns.pairplot(df, hue='entries' )

# %%
fig = plt.figure(figsize= (40, 40))

df.groupby(['station', 'linename'])[["entries"]].sum().sort_values('entries',ascending =False).head(30).plot(figsize= (40, 40),kind= 'barh')
plt.yticks(fontsize = 45)

# %%
fig = plt.figure(figsize= (40, 40))

df.groupby(['station', 'linename'])[["entries"]].sum().sort_values('entries',ascending =False).head(30).plot(figsize= (40, 40),kind= 'barh')
plt.yticks(fontsize = 45)

# %%
df23.groupby(['station', 'linename'])[["entries"]].median().sort_values('entries',ascending =False).head(20).plot(kind= 'barh')

# %%
df.groupby(['station' ])[["entries"]].median().sort_values('entries',ascending =False).head(20).plot(kind= 'barh')

# %%
df.groupby(['station' ])[["entries"]].mean().sort_values('entries',ascending =False).head(20).plot(kind= 'barh')

# %%
df.groupby(['station', 'datetime']).mean().sort_values('entries', ascending =False)

# %%
df["datetime"] = pd.to_datetime(df.date + " " +df.time, format="%m/%d/%Y %H:%M:%S")

# %%
len(df)
# Out:
# 787771

# %%
# We can drop our index if we chose to.
df.isnull()
#turnstiles_df=turnstiles_df.reset_index()
#turnstiles_df=turnstiles_df.drop('index',1)
#turnstiles_df.tail()
# Out:
#         station   date   time  entries  \
# 0         False  False  False    False
# 1         False  False  False    False
# 2         False  False  False    False
# 3         False  False  False    False
# 4         False  False  False    False
# 5         False  False  False    False
# 6         False  False  False    False
# 7         False  False  False    False
# 8         False  False  False    False
# 9         False  False  False    False
# 10        False  False  False    False
# 11        False  False  False    False
# 12        False  False  False    False
# 13        False  False  False    False
# 14        False  False  False    False
# 15        False  False  False    False
# 16        False  False  False    False
# 17        False  False  False    False
# 18        False  False  False    False
# 19        False  False  False    False
# 20        False  False  False    False
# 21        False  False  False    False
# 22        False  False  False    False
# 23        False  False  False    False
# 24        False  False  False    False
# 25        False  False  False    False
# 26        False  False  False    False
# 27        False  False  False    False
# 28        False  False  False    False
# 29        False  False  False    False
# ...         ...    ...    ...      ...
# 195445    False  False  False    False
# 195446    False  False  False    False
# 195447    False  False  False    False
# 195448    False  False  False    False
# 195449    False  False  False    False
# 195450    False  False  False    False
# 195451    False  False  False    False
# 195452    False  False  False    False
# 195453    False  False  False    False
# 195454    False  False  False    False
# 195455    False  False  False    False
# 195456    False  False  False    False
# 195457    False  False  False    False
# 195458    False  False  False    False
# 195459    False  False  False    False
# 195460    False  False  False    False
# 195461    False  False  False    False
# 195462    False  False  False    False
# 195463    False  False  False    False
# 195464    False  False  False    False
# 195465    False  False  False    False
# 195466    False  False  False    False
# 195467    False  False  False    False
# 195468    False  False  False    False
# 195469    False  False  False    False
# 195470    False  False  False    False
# 195471    False  False  False    False
# 195472    False  False  False    False
# 195473    False  False  False    False
# 195474    False  False  False    False
#
#         exits                                                                 \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# 5                                                   False
# 6                                                   False
# 7                                                   False
# 8                                                   False
# 9                                                   False
# 10                                                  False
# 11                                                  False
# 12                                                  False
# 13                                                  False
# 14                                                  False
# 15                                                  False
# 16                                                  False
# 17                                                  False
# 18                                                  False
# 19                                                  False
# 20                                                  False
# 21                                                  False
# 22                                                  False
# 23                                                  False
# 24                                                  False
# 25                                                  False
# 26                                                  False
# 27                                                  False
# 28                                                  False
# 29                                                  False
# ...                                                   ...
# 195445                                              False
# 195446                                              False
# 195447                                              False
# 195448                                              False
# 195449                                              False
# 195450                                              False
# 195451                                              False
# 195452                                              False
# 195453                                              False
# 195454                                              False
# 195455                                              False
# 195456                                              False
# 195457                                              False
# 195458                                              False
# 195459                                              False
# 195460                                              False
# 195461                                              False
# 195462                                              False
# 195463                                              False
# 195464                                              False
# 195465                                              False
# 195466                                              False
# 195467                                              False
# 195468                                              False
# 195469                                              False
# 195470                                              False
# 195471                                              False
# 195472                                              False
# 195473                                              False
# 195474                                              False
#
#         datetime
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
# ...          ...
# 195445     False
# 195446     False
# 195447     False
# 195448     False
# 195449     False
# 195450     False
# 195451     False
# 195452     False
# 195453     False
# 195454     False
# 195455     False
# 195456     False
# 195457     False
# 195458     False
# 195459     False
# 195460     False
# 195461     False
# 195462     False
# 195463     False
# 195464     False
# 195465     False
# 195466     False
# 195467     False
# 195468     False
# 195469     False
# 195470     False
# 195471     False
# 195472     False
# 195473     False
# 195474     False
#
# [787771 rows x 6 columns]

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'ENTRIES', 'DATE_TIME'],
#       dtype='object')

# %%
# major space issue on exits
turnstiles_df.columns = [column.strip() for column in turnstiles_df.columns]

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'ENTRIES', 'DATE_TIME'],
#       dtype='object')

# %%
turnstiles_df.head()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 195462  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195461  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195460  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195459  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195458  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
#
#             TIME  ENTRIES           DATE_TIME
# 195462  21:00:00     5554 2017-05-26 21:00:00
# 195461  17:00:00     5554 2017-05-26 17:00:00
# 195460  13:00:00     5554 2017-05-26 13:00:00
# 195459  09:00:00     5554 2017-05-26 09:00:00
# 195458  05:00:00     5554 2017-05-26 05:00:00

# %%
# Three weeks of Data
turnstiles_df.DATE.value_counts().sort_index()
# Out:
# 03/25/2017    28119
# 03/26/2017    28152
# 03/27/2017    28903
# 03/28/2017    28379
# 03/29/2017    28283
# 03/30/2017    28375
# 03/31/2017    28157
# 04/01/2017    28080
# 04/02/2017    27999
# 04/03/2017    28411
# 04/04/2017    28266
# 04/05/2017    28345
# 04/06/2017    28187
# 04/07/2017    28357
# 04/08/2017    28088
# 04/09/2017    28014
# 04/10/2017    28373
# 04/11/2017    28211
# 04/12/2017    31452
# 04/13/2017    28679
# 04/14/2017    28380
# 04/15/2017    27976
# 04/16/2017    28096
# 04/17/2017    28338
# 04/18/2017    28400
# 04/19/2017    28240
# 04/20/2017    28289
# 04/21/2017    28022
# 04/22/2017    28011
# 04/23/2017    28181
#               ...
# 04/27/2017    28672
# 04/28/2017    28059
# 04/29/2017    28387
# 04/30/2017    28041
# 05/01/2017    28082
# 05/02/2017    28165
# 05/03/2017    28115
# 05/04/2017    28494
# 05/05/2017    28006
# 05/06/2017    28023
# 05/07/2017    27946
# 05/08/2017    28693
# 05/09/2017    28344
# 05/10/2017    28104
# 05/11/2017    27908
# 05/12/2017    27843
# 05/13/2017    27993
# 05/14/2017    27983
# 05/15/2017    28150
# 05/16/2017    28081
# 05/17/2017    27977
# 05/18/2017    27845
# 05/19/2017    27446
# 05/20/2017    27908
# 05/21/2017    27877
# 05/22/2017    27925
# 05/23/2017    27979
# 05/24/2017    28055
# 05/25/2017    27953
# 05/26/2017    27766
# Name: DATE, Length: 63, dtype: int64

# %% [markdown]
# #### Exercise 1.2
#
# - Let's turn this into a time series.
#
#  For each key (basically the control area, unit, device address and
#  station of a specific turnstile), have a list again, but let the list
#  be comprised of just the point in time and the count of entries.
#
# **This basically means keeping only the date, time, and entries fields
# in each list.** You can convert the date and time into datetime objects
# -- That is a python class that represents a point in time. You can
# combine the date and time fields into a string and use the
# [dateutil](https://labix.org/python-dateutil) module to convert it
# into a datetime object. For an example check
# [this StackOverflow question](http://stackoverflow.com/questions/23385003/attributeerror-when-using-import-dateutil-and-dateutil-parser-parse-but-no).
#
# Your new dict should look something like
#
# {    ('A002','R051','02-00-00','LEXINGTON AVE'):
# [
# [datetime.datetime(2013, 3, 2, 3, 0), 3788],
# [datetime.datetime(2013, 3, 2, 7, 0), 2585],
# [datetime.datetime(2013, 3, 2, 12, 0), 10653],
# [datetime.datetime(2013, 3, 2, 17, 0), 11016],
# [datetime.datetime(2013, 3, 2, 23, 0), 10666],
# [datetime.datetime(2013, 3, 3, 3, 0), 10814],
# [datetime.datetime(2013, 3, 3, 7, 0), 10229],
# ...
# ],
# ....
# }

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
from datetime import datetime as dt

# %%
# develop filter, .. 
mask = ((turnstiles_df["C/A"] == "A002") & 
        (turnstiles_df["UNIT"] == "R051") & 
        (turnstiles_df["SCP"] == "02-00-00") & 
        (turnstiles_df["STATION"] == "59 ST"))
turnstiles_df[mask].head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6108321  2069313
# 1  REGULAR  6108343  2069319
# 2  REGULAR  6108360  2069347
# 3  REGULAR  6108462  2069456
# 4  REGULAR  6108689  2069525

# %%
# Convert date and time fields into a single datetime column
turnstiles_df["DATE_TIME"] = pd.to_datetime(turnstiles_df.DATE + " " +turnstiles_df.TIME, format="%m/%d/%Y %H:%M:%S")

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME
# 0  REGULAR  6108321  2069313 2017-03-25 00:00:00
# 1  REGULAR  6108343  2069319 2017-03-25 04:00:00
# 2  REGULAR  6108360  2069347 2017-03-25 08:00:00
# 3  REGULAR  6108462  2069456 2017-03-25 12:00:00
# 4  REGULAR  6108689  2069525 2017-03-25 16:00:00

# %%
mask = ((turnstiles_df["C/A"] == "R626") & 
(turnstiles_df["UNIT"] == "R062") & 
(turnstiles_df["SCP"] == "00-00-00") & 
(turnstiles_df["STATION"] == "CROWN HTS-UTICA"))
turnstiles_df[mask].head()
# Out:
#          C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 191958  R626  R062  00-00-00  CROWN HTS-UTICA       34      IRT  03/25/2017
# 191959  R626  R062  00-00-00  CROWN HTS-UTICA       34      IRT  03/25/2017
# 191960  R626  R062  00-00-00  CROWN HTS-UTICA       34      IRT  03/25/2017
# 191961  R626  R062  00-00-00  CROWN HTS-UTICA       34      IRT  03/25/2017
# 191962  R626  R062  00-00-00  CROWN HTS-UTICA       34      IRT  03/25/2017
#
#             TIME     DESC   ENTRIES    EXITS           DATE_TIME
# 191958  00:00:00  REGULAR  12696601  2825188 2017-03-25 00:00:00
# 191959  04:00:00  REGULAR  12696616  2825205 2017-03-25 04:00:00
# 191960  08:00:00  REGULAR  12696858  2825225 2017-03-25 08:00:00
# 191961  12:00:00  REGULAR  12697359  2825279 2017-03-25 12:00:00
# 191962  16:00:00  REGULAR  12697841  2825378 2017-03-25 16:00:00

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#           C/A  UNIT       SCP          STATION           DATE_TIME  ENTRIES
# 248835   G001  R151  00-00-00  CONEY IS-STILLW 2017-05-09 05:00:00        2
# 729136   N329  R201  00-00-00   WOODHAVEN BLVD 2017-04-28 05:00:00        2
# 1579312  R504  R276  00-00-01   VERNON-JACKSON 2017-05-26 20:00:00        2
# 0        A002  R051  02-00-00            59 ST 2017-03-25 00:00:00        1
# 1185274  R143  R032  02-03-03   TIMES SQ-42 ST 2017-04-22 20:00:00        1

# %%
# On 9/16, we seem to have two entries for same time.  Let's take a look
mask = ((turnstiles_df["C/A"] == "R504") & 
(turnstiles_df["UNIT"] == "R276") & 
(turnstiles_df["SCP"] == "00-00-01") & 
(turnstiles_df["STATION"] == "VERNON-JACKSON") &
# get datetime properties ~ .dt
(turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2016, 9, 16).date()))
turnstiles_df[mask].head()
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, LINENAME, DIVISION, DATE, TIME, DESC, ENTRIES, EXITS, DATE_TIME]
# Index: []

# %% [markdown]
# * Looks to be a incorrect AUD entry.  May be we should just select the Regular One.

# %%
turnstiles_df.DESC.value_counts()
# Out:
# REGULAR       1771043
# RECOVR AUD       6877
# Name: DESC, dtype: int64

# %% [markdown]
# * Since we are only interested in Entries, we might be OK.

# %%
turnstiles_df.sort_values(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True, ascending=False)
# Get rid of the duplicate entry, be default we'll keep first entry
turnstiles_df.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#           C/A  UNIT       SCP         STATION           DATE_TIME  ENTRIES
# 0        A002  R051  02-00-00           59 ST 2017-03-25 00:00:00        1
# 1185274  R143  R032  02-03-03  TIMES SQ-42 ST 2017-04-22 20:00:00        1
# 1185285  R143  R032  02-03-03  TIMES SQ-42 ST 2017-04-24 16:00:00        1
# 1185284  R143  R032  02-03-03  TIMES SQ-42 ST 2017-04-24 12:00:00        1
# 1185283  R143  R032  02-03-03  TIMES SQ-42 ST 2017-04-24 08:00:00        1

# %% [markdown]
# * No more duplicate Entries

# %%
# Drop Exits and Desc Column.  To prevent errors in multiple run of cell, errors on drop is ignored
turnstiles_df = turnstiles_df.drop(["EXITS", "DESC"], axis=1, errors="ignore")
turnstiles_df.head()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 195462  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195461  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195460  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195459  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195458  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
#
#             TIME  ENTRIES           DATE_TIME
# 195462  21:00:00     5554 2017-05-26 21:00:00
# 195461  17:00:00     5554 2017-05-26 17:00:00
# 195460  13:00:00     5554 2017-05-26 13:00:00
# 195459  09:00:00     5554 2017-05-26 09:00:00
# 195458  05:00:00     5554 2017-05-26 05:00:00

# %% [markdown]
# #### Exercise 1.3
#
# - **These counts are for every n hours. (What is n?) We want total daily
#   entries.**
#
# Now make it that we again have the same keys, but now we have a single
# value for a single day, which is the total number of passengers that
# entered through this turnstile on this day.

# %%
# returns a series
turnstiles_daily = turnstiles_df.groupby\
                (["C/A", "UNIT", "SCP", "STATION", "DATE"])\
                .ENTRIES.first().reset_index()
        
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES
# 0  A002  R051  02-00-00   59 ST  03/25/2017  6108983
# 1  A002  R051  02-00-00   59 ST  03/26/2017  6109694
# 2  A002  R051  02-00-00   59 ST  03/27/2017  6111126
# 3  A002  R051  02-00-00   59 ST  03/28/2017  6112613
# 4  A002  R051  02-00-00   59 ST  03/29/2017  6114235

# %%
## TODO comment one of these out

# %%
# define two new columns using 
turnstiles_daily[["PREV_DATE", "PREV_ENTRIES"]] = (turnstiles_daily
                                                       .groupby(["C/A", "UNIT", "SCP", "STATION"])["DATE", "ENTRIES"]
                                                       .transform(lambda grp: grp.shift(1)))
##TRANSFORM

# %%
# define two new columns using 
turnstiles_daily[["PREV_DATE", "PREV_ENTRIES"]] = (turnstiles_daily
                                                       .groupby(["C/A", "UNIT", "SCP", "STATION"])
                                                       ["DATE", "ENTRIES"]
                                                       .shift())

# %%
turnstiles_daily.head(50)
# Out:
#      C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 0   A002  R051  02-00-00   59 ST  03/25/2017  6108983         NaN
# 1   A002  R051  02-00-00   59 ST  03/26/2017  6109694  03/25/2017
# 2   A002  R051  02-00-00   59 ST  03/27/2017  6111126  03/26/2017
# 3   A002  R051  02-00-00   59 ST  03/28/2017  6112613  03/27/2017
# 4   A002  R051  02-00-00   59 ST  03/29/2017  6114235  03/28/2017
# 5   A002  R051  02-00-00   59 ST  03/30/2017  6115846  03/29/2017
# 6   A002  R051  02-00-00   59 ST  03/31/2017  6117403  03/30/2017
# 7   A002  R051  02-00-00   59 ST  04/01/2017  6118355  03/31/2017
# 8   A002  R051  02-00-00   59 ST  04/02/2017  6119175  04/01/2017
# 9   A002  R051  02-00-00   59 ST  04/03/2017  6120725  04/02/2017
# 10  A002  R051  02-00-00   59 ST  04/04/2017  6122229  04/03/2017
# 11  A002  R051  02-00-00   59 ST  04/05/2017  6123787  04/04/2017
# 12  A002  R051  02-00-00   59 ST  04/06/2017  6125319  04/05/2017
# 13  A002  R051  02-00-00   59 ST  04/07/2017  6126998  04/06/2017
# 14  A002  R051  02-00-00   59 ST  04/08/2017  6128002  04/07/2017
# 15  A002  R051  02-00-00   59 ST  04/09/2017  6128747  04/08/2017
# 16  A002  R051  02-00-00   59 ST  04/10/2017  6130163  04/09/2017
# 17  A002  R051  02-00-00   59 ST  04/11/2017  6131601  04/10/2017
# 18  A002  R051  02-00-00   59 ST  04/12/2017  6133044  04/11/2017
# 19  A002  R051  02-00-00   59 ST  04/13/2017  6134780  04/12/2017
# 20  A002  R051  02-00-00   59 ST  04/14/2017  6136338  04/13/2017
# 21  A002  R051  02-00-00   59 ST  04/15/2017  6137520  04/14/2017
# 22  A002  R051  02-00-00   59 ST  04/16/2017  6138260  04/15/2017
# 23  A002  R051  02-00-00   59 ST  04/17/2017  6139650  04/16/2017
# 24  A002  R051  02-00-00   59 ST  04/18/2017  6141533  04/17/2017
# 25  A002  R051  02-00-00   59 ST  04/19/2017  6143374  04/18/2017
# 26  A002  R051  02-00-00   59 ST  04/20/2017  6145464  04/19/2017
# 27  A002  R051  02-00-00   59 ST  04/21/2017  6147769  04/20/2017
# 28  A002  R051  02-00-00   59 ST  04/22/2017  6148910  04/21/2017
# 29  A002  R051  02-00-00   59 ST  04/23/2017  6149818  04/22/2017
# 30  A002  R051  02-00-00   59 ST  04/24/2017  6151473  04/23/2017
# 31  A002  R051  02-00-00   59 ST  04/25/2017  6152823  04/24/2017
# 32  A002  R051  02-00-00   59 ST  04/26/2017  6154302  04/25/2017
# 33  A002  R051  02-00-00   59 ST  04/27/2017  6155892  04/26/2017
# 34  A002  R051  02-00-00   59 ST  04/28/2017  6157479  04/27/2017
# 35  A002  R051  02-00-00   59 ST  04/29/2017  6158521  04/28/2017
# 36  A002  R051  02-00-00   59 ST  04/30/2017  6159015  04/29/2017
# 37  A002  R051  02-00-00   59 ST  05/01/2017  6160374  04/30/2017
# 38  A002  R051  02-00-00   59 ST  05/02/2017  6161830  05/01/2017
# 39  A002  R051  02-00-00   59 ST  05/03/2017  6163254  05/02/2017
# 40  A002  R051  02-00-00   59 ST  05/04/2017  6164865  05/03/2017
# 41  A002  R051  02-00-00   59 ST  05/05/2017  6166192  05/04/2017
# 42  A002  R051  02-00-00   59 ST  05/06/2017  6167090  05/05/2017
# 43  A002  R051  02-00-00   59 ST  05/07/2017  6167857  05/06/2017
# 44  A002  R051  02-00-00   59 ST  05/08/2017  6169303  05/07/2017
# 45  A002  R051  02-00-00   59 ST  05/09/2017  6170839  05/08/2017
# 46  A002  R051  02-00-00   59 ST  05/10/2017  6172382  05/09/2017
# 47  A002  R051  02-00-00   59 ST  05/11/2017  6173936  05/10/2017
# 48  A002  R051  02-00-00   59 ST  05/12/2017  6175691  05/11/2017
# 49  A002  R051  02-00-00   59 ST  05/13/2017  6176686  05/12/2017
#
#     PREV_ENTRIES
# 0            NaN
# 1      6108983.0
# 2      6109694.0
# 3      6111126.0
# 4      6112613.0
# 5      6114235.0
# 6      6115846.0
# 7      6117403.0
# 8      6118355.0
# 9      6119175.0
# 10     6120725.0
# 11     6122229.0
# 12     6123787.0
# 13     6125319.0
# 14     6126998.0
# 15     6128002.0
# 16     6128747.0
# 17     6130163.0
# 18     6131601.0
# 19     6133044.0
# 20     6134780.0
# 21     6136338.0
# 22     6137520.0
# 23     6138260.0
# 24     6139650.0
# 25     6141533.0
# 26     6143374.0
# 27     6145464.0
# 28     6147769.0
# 29     6148910.0
# 30     6149818.0
# 31     6151473.0
# 32     6152823.0
# 33     6154302.0
# 34     6155892.0
# 35     6157479.0
# 36     6158521.0
# 37     6159015.0
# 38     6160374.0
# 39     6161830.0
# 40     6163254.0
# 41     6164865.0
# 42     6166192.0
# 43     6167090.0
# 44     6167857.0
# 45     6169303.0
# 46     6170839.0
# 47     6172382.0
# 48     6173936.0
# 49     6175691.0

# %%
# Drop rows for first date
turnstiles_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  PREV_ENTRIES
# 1  A002  R051  02-00-00   59 ST  03/26/2017  6109694  03/25/2017     6108983.0
# 2  A002  R051  02-00-00   59 ST  03/27/2017  6111126  03/26/2017     6109694.0
# 3  A002  R051  02-00-00   59 ST  03/28/2017  6112613  03/27/2017     6111126.0
# 4  A002  R051  02-00-00   59 ST  03/29/2017  6114235  03/28/2017     6112613.0
# 5  A002  R051  02-00-00   59 ST  03/30/2017  6115846  03/29/2017     6114235.0

# %%
# sanity check : when are previous entries greater than current ? 
turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]].head()
# Out:
#        C/A  UNIT       SCP     STATION        DATE    ENTRIES   PREV_DATE  \
# 2004  A010  R080  00-00-05  57 ST-7 AV  05/15/2017       3576  05/14/2017
# 2143  A011  R080  01-00-00  57 ST-7 AV  03/26/2017  887121864  03/25/2017
# 2144  A011  R080  01-00-00  57 ST-7 AV  03/27/2017  887119135  03/26/2017
# 2145  A011  R080  01-00-00  57 ST-7 AV  03/28/2017  887115773  03/27/2017
# 2146  A011  R080  01-00-00  57 ST-7 AV  03/29/2017  887112335  03/28/2017
#
#       PREV_ENTRIES
# 2004      430596.0
# 2143   887123728.0
# 2144   887121864.0
# 2145   887119135.0
# 2146   887115773.0

# %%
# What's the deal with counter going in reverse ? 
# investigate this with turnstiles_df
mask = ((turnstiles_df["C/A"] == "A011") & 
(turnstiles_df["UNIT"] == "R080") & 
(turnstiles_df["SCP"] == "01-00-00") & 
(turnstiles_df["STATION"] == "57 ST-7 AV") &
(turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2016, 8, 27).date()))
turnstiles_df[mask].head()

# entries going up, datetime going down
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, LINENAME, DIVISION, DATE, TIME, ENTRIES, DATE_TIME]
# Index: []

# %% [markdown]
# * Counter working in Reverse??? - WHHHAT

# %%
# Let's see how many stations have this problem

(turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
     .size())

# size vs count? 
# size includes NaN values, count does not
# Out:
# C/A    UNIT  SCP       STATION
# A010   R080  00-00-05  57 ST-7 AV          1
# A011   R080  01-00-00  57 ST-7 AV         62
# A025   R023  01-03-01  34 ST-HERALD SQ    62
#              01-03-02  34 ST-HERALD SQ    62
# A035   R170  00-00-01  14 ST-UNION SQ      6
# A037   R170  05-00-00  14 ST-UNION SQ      1
# A043   R462  00-06-00  CANAL ST            1
# A049   R088  02-05-00  CORTLANDT ST       44
# A054   R227  01-06-00  RECTOR ST           1
# A060   R001  00-00-06  WHITEHALL S-FRY     1
# A066   R118  00-00-00  CANAL ST           62
# A071   R044  02-00-02  CHAMBERS ST         1
# B016   R098  00-03-01  CHURCH AV           1
# B022   R229  00-05-00  AVENUE M            1
# B029   R172  00-00-01  BRIGHTON BEACH      1
# C012   R258  01-06-00  4AV-9 ST            1
# C019   R232  00-00-02  45 ST               2
# C021   R212  00-00-02  59 ST              35
# D005   R398  00-06-00  NEW UTRECHT AV      1
# E013   R373  00-00-02  20 AV               1
# H003   R163  01-00-02  6 AV               62
# H023   R236  00-06-00  DEKALB AV          60
# H037   R349  00-00-00  SUTTER AV           1
# H038   R350  00-06-01  LIVONIA AV          1
# H041   R152  00-05-01  CANARSIE-ROCKAW     1
# J024   R437  00-00-00  CRESCENT ST         1
# J034   R007  00-00-02  104 ST             58
# JFK01  R535  00-00-02  HOWARD BCH JFK      1
# JFK03  R536  00-00-01  JFK JAMAICA CT1     1
#              00-00-05  JFK JAMAICA CT1     1
#                                           ..
# R178   R273  00-00-02  145 ST              1
#              00-00-03  145 ST              1
# R192   R039  00-06-00  MARBLE HILL-225     1
# R210   R044  00-03-04  BROOKLYN BRIDGE    62
# R227   R131  00-00-00  23 ST              62
# R240   R047  00-00-01  GRD CNTRL-42 ST     1
# R241A  R048  00-00-00  GRD CNTRL-42 ST    22
#              00-00-04  GRD CNTRL-42 ST     1
# R245   R051  00-00-00  59 ST              62
# R251   R144  00-03-02  96 ST               1
# R252   R180  00-03-00  103 ST              1
# R258   R132  00-00-03  125 ST             62
# R304   R206  00-00-00  125 ST             62
# R305   R206  01-00-02  125 ST             62
# R310   R053  01-00-02  3 AV-149 ST        62
#              01-00-04  3 AV-149 ST         1
# R322   R386  00-00-02  174 ST             62
# R501   R054  00-00-00  5 AVE               1
# R515   R095  00-00-03  ASTORIA DITMARS     1
# R524   R347  00-05-00  69 ST               1
# R532H  R328  02-03-05  METS-WILLETS PT     1
# R621   R060  00-03-01  EASTN PKWY-MUSM     1
# R622   R123  00-00-00  FRANKLIN AV        62
# R646   R110  01-00-01  FLATBUSH AV-B.C    62
# R730   R431  00-00-04  EASTCHSTER/DYRE    18
# S101A  R070  01-03-02  ST. GEORGE          1
# S102   R165  00-05-01  TOMPKINSVILLE       1
# TRAM1  R468  00-00-00  RIT-MANHATTAN       1
#              00-00-01  RIT-MANHATTAN       1
#              00-05-00  RIT-MANHATTAN       1
# Length: 154, dtype: int64

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        # see how large these values get..
        print(row["ENTRIES"], row["PREV_ENTRIES"])
        return 0
    return counter

# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
_ = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 1810 1272207.0
# 371 100838424.0
# 96 2605955.0
# 574 4607298.0
# 16796105 61127.0
# 142 16796105.0
# 2802 6926320.0
# 837 284994121.0
# 2031088564 10518173.0
# 117484783 471260.0
# 458752 4773394.0
# 1946191222 7661697.0
# 231 7586045.0
# 1425 11823537.0
# 838882038 3322932.0
# 342 7896924.0
# 976 5439401.0
# 262190 6576459.0
# 2438 9417254.0
# 83942693 381404.0
# 33554825 3050267.0
# 52 1946567.0
# 4532 8036361.0
# 659 665415304.0
# 145 3879912.0
# 2164 13435856.0
# 117440514 2582.0
# 1929349962 9255304.0
# 2224 16799815.0
# 1346 1356336.0
# 954 3410129.0
# 67108920 442042.0
# 1633 1558447.0
# 117440513 471859.0
# 691259285 8105279.0
# 1074 16660967.0
# 288 5961768.0
# 1448 10512102.0
# 646 2525748.0
# 183 605785512.0
# 44 13531479.0
# 1882 9700114.0
# 632 537737953.0
# 119 50337328.0
# 100710824 344567.0
# 4241 20236930.0
# 503286695 14838374.0
# 1370 856595404.0
# 70041 19461075.0
# 33554892 2724829.0
# 1050 2136240.0
# 67108867 887.0
# 134218754 573098.0
# 335580007 1356852.0
# 117442931 19188583.0
# 1560221276 2525075.0
# 3610141 538709.0
# 540628 3610141.0

# %%
# slightly different approach
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        # May be counter is reversed?
        counter = -counter
    if counter > max_counter:
        print(row["ENTRIES"], row["PREV_ENTRIES"],row['C/A'],row['UNIT'],
             row['SCP'],row['STATION'])
        # assumption is that 
        counter = min(row["ENTRIES"], row["PREV_ENTRIES"])
    if counter > max_counter:
        # Check it again to make sure we are not giving a counter that's too big
        return 0
    return counter

# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
turnstiles_daily["DAILY_ENTRIES"] = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 1810 1272207.0 A037 R170 05-00-00 14 ST-UNION SQ
# 371 100838424.0 A054 R227 01-06-00 RECTOR ST
# 96 2605955.0 A071 R044 02-00-02 CHAMBERS ST
# 574 4607298.0 B016 R098 00-03-01 CHURCH AV
# 16796105 61127.0 B022 R229 00-05-00 AVENUE M
# 142 16796105.0 B022 R229 00-05-00 AVENUE M
# 2802 6926320.0 B029 R172 00-00-01 BRIGHTON BEACH
# 837 284994121.0 C019 R232 00-00-02 45 ST
# 2031088564 10518173.0 C021 R212 00-00-02 59 ST
# 117484783 471260.0 C026 R215 01-06-01 86 ST
# 458752 4773394.0 D005 R398 00-06-00 NEW UTRECHT AV
# 1946191222 7661697.0 D008 R392 00-00-02 18 AV
# 231 7586045.0 E013 R373 00-00-02 20 AV
# 1425 11823537.0 H037 R349 00-00-00 SUTTER AV
# 838882038 3322932.0 J005 R353 00-06-00 LORIMER ST
# 342 7896924.0 J024 R437 00-00-00 CRESCENT ST
# 976 5439401.0 N063 R011 02-00-00 42 ST-PORT AUTH
# 262190 6576459.0 N068 R012 03-06-00 34 ST-PENN STA
# 2438 9417254.0 N070 R012 04-00-03 34 ST-PENN STA
# 83942693 381404.0 N138 R355 01-06-01 111 ST
# 33554825 3050267.0 N223 R156 01-06-01 BEDFORD PK BLVD
# 52 1946567.0 N319 R298 01-06-01 NORTHERN BLVD
# 4532 8036361.0 N324 R018 00-03-01 JKSN HT-ROOSVLT
# 659 665415304.0 N325A R218 00-05-01 ELMHURST AV
# 145 3879912.0 N338 R128 01-06-00 SUTPHIN BLVD
# 2164 13435856.0 N501 R020 01-03-03 47-50 STS ROCK
# 117440514 2582.0 N550 R242 01-05-00 18 AV
# 1929349962 9255304.0 N600 R302 00-06-00 57 ST
# 2224 16799815.0 N700A R570 01-00-03 72 ST-2 AVE
# 1346 1356336.0 PTH03 R552 00-00-02 JOURNAL SQUARE
# 954 3410129.0 R133 R272 00-00-03 28 ST
# 67108920 442042.0 R148 R033 01-06-01 TIMES SQ-42 ST
# 1633 1558447.0 R158 R084 00-06-02 59 ST COLUMBUS
# 117440513 471859.0 R160A R164 00-05-00 66 ST-LINCOLN
# 691259285 8105279.0 R161B R452 00-00-03 72 ST
# 1074 16660967.0 R162 R166 00-00-00 79 ST
# 288 5961768.0 R165 R167 01-00-02 86 ST
# 1448 10512102.0 R165 R167 01-00-04 86 ST
# 646 2525748.0 R169 R168 01-00-02 96 ST
# 183 605785512.0 R169 R168 01-03-01 96 ST
# 44 13531479.0 R170 R191 00-00-00 103 ST
# 1882 9700114.0 R178 R273 00-00-02 145 ST
# 632 537737953.0 R178 R273 00-00-03 145 ST
# 119 50337328.0 R192 R039 00-06-00 MARBLE HILL-225
# 100710824 344567.0 R228 R143 00-00-04 28 ST
# 4241 20236930.0 R240 R047 00-00-01 GRD CNTRL-42 ST
# 503286695 14838374.0 R241A R048 00-00-00 GRD CNTRL-42 ST
# 1370 856595404.0 R241A R048 00-00-04 GRD CNTRL-42 ST
# 70041 19461075.0 R251 R144 00-03-02 96 ST
# 33554892 2724829.0 R287 R244 00-05-00 BURNSIDE AV
# 1050 2136240.0 R310 R053 01-00-04 3 AV-149 ST
# 67108867 887.0 R311 R053 00-05-00 3 AV-149 ST
# 134218754 573098.0 R327 R361 01-06-00 PELHAM PKWY
# 335580007 1356852.0 R417 R222 00-00-04 PARKCHESTER
# 117442931 19188583.0 R602 R108 00-06-01 BOROUGH HALL
# 1560221276 2525075.0 R730 R431 00-00-04 EASTCHSTER/DYRE
# 3610141 538709.0 TRAM1 R468 00-00-00 RIT-MANHATTAN
# 540628 3610141.0 TRAM1 R468 00-00-00 RIT-MANHATTAN

# %%
# Daily_Entries
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  03/26/2017  6109694  03/25/2017
# 2  A002  R051  02-00-00   59 ST  03/27/2017  6111126  03/26/2017
# 3  A002  R051  02-00-00   59 ST  03/28/2017  6112613  03/27/2017
# 4  A002  R051  02-00-00   59 ST  03/29/2017  6114235  03/28/2017
# 5  A002  R051  02-00-00   59 ST  03/30/2017  6115846  03/29/2017
#
#    PREV_ENTRIES  DAILY_ENTRIES
# 1     6108983.0          711.0
# 2     6109694.0         1432.0
# 3     6111126.0         1487.0
# 4     6112613.0         1622.0
# 5     6114235.0         1611.0

# %%
# Verify that we got same results via the non-pandas version.

# %%
turnstiles_daily.groupby('STATION').mean().sort_values('DAILY_ENTRIES', ascending=False).DAILY_ENTRIES.head(20).plot(kind='barh')

# %%
df =turnstiles_daily.groupby('STATION').mean().\
sort_values('DAILY_ENTRIES', ascending=False).add_prefix('mean_')
print (df)
# Out:
#                  mean_ENTRIES  mean_PREV_ENTRIES  mean_DAILY_ENTRIES
# STATION
# RIT-MANHATTAN    1.062200e+06       1.061217e+06         5646.241667
# YORK ST          1.183296e+07       1.182968e+07         3282.580645
# MYRTLE AV        8.442869e+06       8.439991e+06         2877.298387
# W 4 ST-WASH SQ   1.994974e+07       1.994831e+07         2876.529711
# 14 ST-UNION SQ   2.896366e+07       2.896144e+07         2871.096815
# 57 ST-7 AV       3.002297e+08       3.002283e+08         2798.252304
# LIVONIA AV       2.481702e+06       2.483252e+06         2679.216129
# NEW UTRECHT AV   3.493100e+06       3.506021e+06         2477.583871
# FRESH POND RD    3.227105e+06       3.224789e+06         2316.151210
# JKSN HT-ROOSVLT  5.938108e+06       5.941787e+06         2309.630402
# 116 ST-COLUMBIA  2.026043e+08       2.026020e+08         2252.779570
# 34 ST-HERALD SQ  8.260774e+07       8.260592e+07         2126.736543
# 30 AV            6.046752e+06       6.044637e+06         2115.623656
# BEDFORD AV       2.063225e+07       2.063014e+07         2109.055831
# MONTROSE AV      4.769461e+07       4.769250e+07         2105.209677
# GRD CNTRL-42 ST  4.783052e+07       4.793043e+07         2090.633237
# 103 ST           9.595863e+06       9.608621e+06         2072.950484
# QUEENSBORO PLZ   6.582134e+06       6.580068e+06         2066.239247
# SUTTER AV        3.779910e+06       3.873196e+06         2065.153226
# 103 ST-CORONA    7.744582e+06       7.742517e+06         2064.482079
# GATES AV         1.746466e+06       1.744405e+06         2060.935484
# NOSTRAND AV      8.302046e+06       8.299989e+06         2056.782258
# 1 AV             1.417112e+08       1.417092e+08         2025.000000
# FLUSHING-MAIN    7.140724e+06       7.138719e+06         2004.726404
# GRAND ST         2.268219e+07       2.268020e+07         1984.966590
# TIMES SQ-42 ST   1.159593e+08       1.159361e+08         1980.389355
# BURNSIDE AV      3.274317e+06       3.172909e+06         1956.819355
# NEWKIRK PLAZA    1.044208e+07       1.044013e+07         1955.361290
# CORTELYOU RD     7.017823e+06       7.015868e+06         1954.446237
# 191 ST           3.031685e+06       3.029731e+06         1953.516129
# ...                       ...                ...                 ...
# AVENUE N         2.462519e+07       2.462480e+07          393.669355
# ZEREGA AV        8.975332e+06       8.974940e+06          391.715054
# BEACH 25 ST      1.518565e+06       1.518195e+06          370.060000
# BOTANIC GARDEN   1.587800e+06       1.587430e+06          369.963710
# NEWARK HW BMEBE  1.155622e+05       1.153933e+05          367.308113
# AVENUE I         2.135356e+06       2.135001e+06          354.736842
# 104 ST           5.346345e+08       5.346342e+08          327.385455
# HOWARD BCH JFK   5.935695e+05       5.934153e+05          323.376997
# 75 AV            4.748135e+07       4.748102e+07          322.698387
# 53 ST            5.875922e+06       5.875604e+06          318.375000
# MIDDLETOWN RD    1.699495e+06       1.699188e+06          306.809140
# WHITLOCK AV      3.733435e+07       3.733406e+07          288.674731
# AQUEDUCT RACETR  8.864135e+06       8.863851e+06          284.639785
# NEWARK C         1.821164e+05       1.818711e+05          272.672352
# W 8 ST-AQUARIUM  1.473656e+06       1.473386e+06          270.114919
# METS-WILLETS PT  1.289998e+06       1.289868e+06          202.947581
# AVENUE H         8.174395e+06       8.174195e+06          199.409677
# 121 ST           1.894829e+06       1.894636e+06          193.645161
# AQUEDUCT N.COND  1.003107e+06       1.002926e+06          180.574194
# BEACH 36 ST      8.662862e+05       8.661069e+05          179.287097
# BEACH 90 ST      1.103046e+06       1.102893e+06          152.625806
# E 143/ST MARY'S  8.326658e+05       8.325250e+05          140.803763
# BEACH 44 ST      5.454636e+05       5.453318e+05          131.806452
# ROCKAWAY PARK B  2.108018e+07       2.108006e+07          120.629032
# TOMPKINSVILLE    1.327021e+06       1.326905e+06          116.736111
# NEWARK HM HE     4.033980e+04       4.029474e+04           99.553749
# BEACH 98 ST      9.185406e+05       9.184527e+05           87.983871
# BROAD CHANNEL    4.050522e+05       4.049648e+05           87.424731
# BEACH 105 ST     2.373715e+07       2.373711e+07           44.916129
# ORCHARD BEACH    9.427567e+04       9.427310e+04            2.566667
#
# [376 rows x 3 columns]

# %%
turnstiles_daily.describe()
turnstiles_daily["DAILY_ENTRIES"].isnull().count()
# Out:
# 290319

# %%
df = turnstiles_daily

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, DATE, ENTRIES, PREV_DATE, PREV_ENTRIES, DAILY_ENTRIES]
# Index: []

# %%
df.describe()
# Out:
#             ENTRIES  PREV_ENTRIES  DAILY_ENTRIES
# count  2.903190e+05  2.903190e+05  290319.000000
# mean   3.712769e+07  3.710108e+07    1198.250893
# std    2.008189e+08  2.007054e+08    5486.315410
# min    0.000000e+00  0.000000e+00       0.000000
# 25%    4.828405e+05  4.827475e+05     297.000000
# 50%    2.600235e+06  2.599999e+06     886.000000
# 75%    6.691528e+06  6.690930e+06    1690.000000
# max    2.130568e+09  2.130568e+09  895492.000000

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#             ENTRIES  PREV_ENTRIES  DAILY_ENTRIES
# count  2.903190e+05  2.903190e+05  290319.000000
# mean   3.712769e+07  3.710108e+07    1198.250893
# std    2.008189e+08  2.007054e+08    5486.315410
# min    0.000000e+00  0.000000e+00       0.000000
# 25%    4.828405e+05  4.827475e+05     297.000000
# 50%    2.600235e+06  2.599999e+06     886.000000
# 75%    6.691528e+06  6.690930e+06    1690.000000
# max    2.130568e+09  2.130568e+09  895492.000000

# %%
df.isnull().count()
# Out:
# C/A              290319
# UNIT             290319
# SCP              290319
# STATION          290319
# DATE             290319
# ENTRIES          290319
# PREV_DATE        290319
# PREV_ENTRIES     290319
# DAILY_ENTRIES    290319
# dtype: int64

# %%
df.dropna()
# Out:
#           C/A  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 1        A002  R051  02-00-00          59 ST  03/26/2017  6109694  03/25/2017
# 2        A002  R051  02-00-00          59 ST  03/27/2017  6111126  03/26/2017
# 3        A002  R051  02-00-00          59 ST  03/28/2017  6112613  03/27/2017
# 4        A002  R051  02-00-00          59 ST  03/29/2017  6114235  03/28/2017
# 5        A002  R051  02-00-00          59 ST  03/30/2017  6115846  03/29/2017
# 6        A002  R051  02-00-00          59 ST  03/31/2017  6117403  03/30/2017
# 7        A002  R051  02-00-00          59 ST  04/01/2017  6118355  03/31/2017
# 8        A002  R051  02-00-00          59 ST  04/02/2017  6119175  04/01/2017
# 9        A002  R051  02-00-00          59 ST  04/03/2017  6120725  04/02/2017
# 10       A002  R051  02-00-00          59 ST  04/04/2017  6122229  04/03/2017
# 11       A002  R051  02-00-00          59 ST  04/05/2017  6123787  04/04/2017
# 12       A002  R051  02-00-00          59 ST  04/06/2017  6125319  04/05/2017
# 13       A002  R051  02-00-00          59 ST  04/07/2017  6126998  04/06/2017
# 14       A002  R051  02-00-00          59 ST  04/08/2017  6128002  04/07/2017
# 15       A002  R051  02-00-00          59 ST  04/09/2017  6128747  04/08/2017
# 16       A002  R051  02-00-00          59 ST  04/10/2017  6130163  04/09/2017
# 17       A002  R051  02-00-00          59 ST  04/11/2017  6131601  04/10/2017
# 18       A002  R051  02-00-00          59 ST  04/12/2017  6133044  04/11/2017
# 19       A002  R051  02-00-00          59 ST  04/13/2017  6134780  04/12/2017
# 20       A002  R051  02-00-00          59 ST  04/14/2017  6136338  04/13/2017
# 21       A002  R051  02-00-00          59 ST  04/15/2017  6137520  04/14/2017
# 22       A002  R051  02-00-00          59 ST  04/16/2017  6138260  04/15/2017
# 23       A002  R051  02-00-00          59 ST  04/17/2017  6139650  04/16/2017
# 24       A002  R051  02-00-00          59 ST  04/18/2017  6141533  04/17/2017
# 25       A002  R051  02-00-00          59 ST  04/19/2017  6143374  04/18/2017
# 26       A002  R051  02-00-00          59 ST  04/20/2017  6145464  04/19/2017
# 27       A002  R051  02-00-00          59 ST  04/21/2017  6147769  04/20/2017
# 28       A002  R051  02-00-00          59 ST  04/22/2017  6148910  04/21/2017
# 29       A002  R051  02-00-00          59 ST  04/23/2017  6149818  04/22/2017
# 30       A002  R051  02-00-00          59 ST  04/24/2017  6151473  04/23/2017
# ...       ...   ...       ...            ...         ...      ...         ...
# 295005  TRAM2  R469  00-05-01  RIT-ROOSEVELT  04/27/2017     5554  04/26/2017
# 295006  TRAM2  R469  00-05-01  RIT-ROOSEVELT  04/28/2017     5554  04/27/2017
# 295007  TRAM2  R469  00-05-01  RIT-ROOSEVELT  04/29/2017     5554  04/28/2017
# 295008  TRAM2  R469  00-05-01  RIT-ROOSEVELT  04/30/2017     5554  04/29/2017
# 295009  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/01/2017     5554  04/30/2017
# 295010  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/02/2017     5554  05/01/2017
# 295011  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/03/2017     5554  05/02/2017
# 295012  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/04/2017     5554  05/03/2017
# 295013  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/05/2017     5554  05/04/2017
# 295014  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/06/2017     5554  05/05/2017
# 295015  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/07/2017     5554  05/06/2017
# 295016  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/08/2017     5554  05/07/2017
# 295017  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/09/2017     5554  05/08/2017
# 295018  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/10/2017     5554  05/09/2017
# 295019  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/11/2017     5554  05/10/2017
# 295020  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/12/2017     5554  05/11/2017
# 295021  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/13/2017     5554  05/12/2017
# 295022  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/14/2017     5554  05/13/2017
# 295023  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/15/2017     5554  05/14/2017
# 295024  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/16/2017     5554  05/15/2017
# 295025  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/17/2017     5554  05/16/2017
# 295026  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/18/2017     5554  05/17/2017
# 295027  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/19/2017     5554  05/18/2017
# 295028  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/20/2017     5554  05/19/2017
# 295029  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/21/2017     5554  05/20/2017
# 295030  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/22/2017     5554  05/21/2017
# 295031  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/23/2017     5554  05/22/2017
# 295032  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/24/2017     5554  05/23/2017
# 295033  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/25/2017     5554  05/24/2017
# 295034  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/26/2017     5554  05/25/2017
#
#         PREV_ENTRIES  DAILY_ENTRIES
# 1          6108983.0          711.0
# 2          6109694.0         1432.0
# 3          6111126.0         1487.0
# 4          6112613.0         1622.0
# 5          6114235.0         1611.0
# 6          6115846.0         1557.0
# 7          6117403.0          952.0
# 8          6118355.0          820.0
# 9          6119175.0         1550.0
# 10         6120725.0         1504.0
# 11         6122229.0         1558.0
# 12         6123787.0         1532.0
# 13         6125319.0         1679.0
# 14         6126998.0         1004.0
# 15         6128002.0          745.0
# 16         6128747.0         1416.0
# 17         6130163.0         1438.0
# 18         6131601.0         1443.0
# 19         6133044.0         1736.0
# 20         6134780.0         1558.0
# 21         6136338.0         1182.0
# 22         6137520.0          740.0
# 23         6138260.0         1390.0
# 24         6139650.0         1883.0
# 25         6141533.0         1841.0
# 26         6143374.0         2090.0
# 27         6145464.0         2305.0
# 28         6147769.0         1141.0
# 29         6148910.0          908.0
# 30         6149818.0         1655.0
# ...              ...            ...
# 295005        5554.0            0.0
# 295006        5554.0            0.0
# 295007        5554.0            0.0
# 295008        5554.0            0.0
# 295009        5554.0            0.0
# 295010        5554.0            0.0
# 295011        5554.0            0.0
# 295012        5554.0            0.0
# 295013        5554.0            0.0
# 295014        5554.0            0.0
# 295015        5554.0            0.0
# 295016        5554.0            0.0
# 295017        5554.0            0.0
# 295018        5554.0            0.0
# 295019        5554.0            0.0
# 295020        5554.0            0.0
# 295021        5554.0            0.0
# 295022        5554.0            0.0
# 295023        5554.0            0.0
# 295024        5554.0            0.0
# 295025        5554.0            0.0
# 295026        5554.0            0.0
# 295027        5554.0            0.0
# 295028        5554.0            0.0
# 295029        5554.0            0.0
# 295030        5554.0            0.0
# 295031        5554.0            0.0
# 295032        5554.0            0.0
# 295033        5554.0            0.0
# 295034        5554.0            0.0
#
# [290319 rows x 9 columns]

# %%
mask = ((turnstiles_df["C/A"] == "A011")
mask = ((turnstiles_df["C/A"] == "A002") & 
        (turnstiles_df["UNIT"] == "R051") & 
        (turnstiles_df["SCP"] == "02-00-00") & 
        (turnstiles_df["STATION"] == "59 ST"))
turnstiles_df[mask].head()

# %%
y= df.DATE
x = df.DAILY_ENTRIES

plt.bar(y,
        x,
        color='blue',
        edgecolor='none',
        width=0.5,
        align='center',
        label='y1')
# Out:
# <Container object of 290319 artists>

# %%
len(df)
# Out:
# 290319
